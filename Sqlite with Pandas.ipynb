# %%
import pandas as pd
import sqlite3

# %%
db = sqlite3.connect('school.sqlite')

# %%
cur = db.cursor()

# %%
data = pd.read_sql_query('Select * from Student', db)
data
# Out:
#     RollNumber      Name  Age
# 0           11   Ibrahim   20
# 1           12  Muhammed   22
# 2          100     Yasin   22
# 3          101      Zayd   27
# 4          102     Yusuf   15
# 5          103     Amina   22
# 6          104    Fatima   21
# 7          105       Ali   25
# 8          106    Hassan   21
# 9          107   Khadija   18
# 10         108      Omar   24
# 11         109    Maryam   20
# 12         110     Bilal   23
# 13         111     Salma   17
# 14         112   Ibrahim   26
# 15         113      Sara   22
# 16         114       Nuh   16
# 17         115      Musa   28
# 18         116    Ismail   19
# 19         117   Sumayya   20
# 20         118     Hamza   25
# 21         119    Zainab   21
# 22         120  Abdullah   23
# 23         121     Yasin   22
# 24         122    Rayyan   18
# 25         123      Huda   24
# 26         124     Tariq   27
# 27         125      Lina   20
# 28         126     Farah   19
# 29         127     Jamal   26
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data[data['Age']==22]
# Out:
#     RollNumber      Name  Age
# 1           12  Muhammed   22
# 2          100     Yasin   22
# 5          103     Amina   22
# 15         113      Sara   22
# 23         121     Yasin   22
# 31         129      Rami   22
# 39         137      Hana   22
# 46         144    Zubair   22

# %%
data = pd.DataFrame([[201,"Aman", "English", 30000], [202, "Amit", "Science", 20300], [203,"Saad", "Kannada",303030]], columns=["ID","Name","Subject","Salary" ])
data
# Out:
#     ID  Name  Subject  Salary
# 0  201  Aman  English   30000
# 1  202  Amit  Science   20300
# 2  203  Saad  Kannada  303030

# %%
data.to_sql("Faculty", db)
# Out:
# 3

# %%
data = pd.read_sql_query("Select * from Student",db)
data["Address"] =
