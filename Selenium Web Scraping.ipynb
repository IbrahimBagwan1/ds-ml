# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.35.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting urllib3<3.0,>=2.5.0 (from urllib3[socks]<3.0,>=2.5.0->selenium)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.6.15 in c:\users\irbag\anaconda3\lib\site-packages (from selenium) (2025.8.3)
# Collecting typing_extensions~=4.14.0 (from selenium)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\irbag\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\irbag\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\irbag\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\irbag\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\irbag\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\irbag\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\irbag\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\irbag\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\irbag\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.35.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/9.6 MB 17.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.6 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 18.2 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, typing_extensions, outcome, trio, trio-websocket, selenium
#
#   Attempting uninstall: urllib3
#
#     Found existing installation: urllib3 2.3.0
#
#     Uninstalling urllib3-2.3.0:
#
#    ----- ---------------------------------- 1/7 [urllib3]
#       Successfully uninstalled urllib3-2.3.0
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#   Attempting uninstall: typing_extensions
#    ----- ---------------------------------- 1/7 [urllib3]
#     Found existing installation: typing_extensions 4.12.2
#    ----- ---------------------------------- 1/7 [urllib3]
#     Uninstalling typing_extensions-4.12.2:
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------------- 7/7 [selenium]
#
# Successfully installed outcome-1.3.0.post0 selenium-4.35.0 trio-0.30.0 trio-websocket-0.12.2 typing_extensions-4.14.1 urllib3-2.5.0 wsproto-1.2.0

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\irbag\anaconda3\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\irbag\anaconda3\lib\site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in c:\users\irbag\anaconda3\lib\site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\irbag\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\irbag\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\irbag\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\irbag\anaconda3\lib\site-packages (from requests->webdriver-manager) (2025.8.3)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# Setup Chrome options
options = Options()
options.add_argument("--headless")  # Run in background
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")

# Use Service to pass the driver path correctly
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Open the site
driver.get("https://greengarden-belgaum.vercel.app")
time.sleep(3)  # Wait for page to load

# Extract heading
heading = driver.find_element(By.TAG_NAME, "h1").text
print("Main Heading:", heading)

# Extract all paragraph text
paragraphs = driver.find_elements(By.TAG_NAME, "p")
for i, p in enumerate(paragraphs):
    print(f"Paragraph {i+1}:", p.text)

# Extract image URLs
images = driver.find_elements(By.TAG_NAME, "img")
for i, img in enumerate(images):
    print(f"Image {i+1} URL:", img.get_attribute("src"))

driver.quit()
# Out:
# Main Heading: Green Garden
# Paragraph 1: Function Hall
# Paragraph 2: Celebrate Your Special Moments at Belagavi’s Affordable & Elegant Function Hall – Perfect for Weddings, Receptions & Family Events
# Paragraph 3: Located in prestigious area near Hanuman Nagar
# Paragraph 4: Alcohol-free, family-friendly environment
# Paragraph 5: Beautifully designed interiors with modern facilities
# Paragraph 6: Located in the prestigious Hanuman Nagar area of Belagavi with exceptional space, excellent Air ventilation, and good managed facilities for your perfect celebration
# Paragraph 7: Spacious hall accommodating large gatherings with comfort
# Paragraph 8: Convenient parking space for 100+ vehicles
# Paragraph 9: Delicious vegetarian & non-vegetarian cuisine
# Paragraph 10: Professional sound system and lighting arrangements
# Paragraph 11: 500+ seating capacity with excellent Air ventilation and high roof system ensuring comfort for all guests throughout your celebration, especially in Summer days the Hall remains cool.
# Paragraph 12: Strategically located near Kumar Swamy Layout area with easy accessibility and peaceful environment for your guests.
# Paragraph 13: Strictly alcohol-free policy ensuring a family-friendly and safe environment for celebrations of all ages and cultural backgrounds.
# Paragraph 14: Hear from families who celebrated their special moments with us at Green Garden Function Hall
# Paragraph 15: "Green Garden made our wedding reception absolutely perfect! The staff was professional, food was delicious, and the venue looked stunning. Our 600 guests were comfortable throughout the event."
# Paragraph 16: Ibrahim Bagwan
# Paragraph 17: Wedding Reception
# Paragraph 18: "Excellent service and amazing food quality. The hall's ambience created the perfect atmosphere for our silver jubilee celebration. The location in Tilakwadi was perfect for our guests."
# Paragraph 19: Anita Sharma
# Paragraph 20: 25th Anniversary
# Paragraph 21: "Professional setup with all modern amenities. The Air ventilationing worked perfectly even with 400 attendees. Highly recommend for corporate events and conferences in Belagavi."
# Paragraph 22: Vikram Industries
# Paragraph 23: Corporate Event
# Paragraph 24: Located in the prestigious Bauxite Road, Near Kumar Swamy Layout area of Belagavi with easy access and ample parking. Come visit us to experience the elegance and grandeur of Green Garden Function Hall.
# Paragraph 25: Near Kumar Swamy Layout, Bauxite Road
# Paragraph 26: Belagavi, Karnataka 590019
# Paragraph 27: +91 9449837586
# Paragraph 28: Call for bookings & inquiries
# Paragraph 29: Function Hall
# Paragraph 30: Belagavi's premier function hall offering elegant venues for weddings, receptions, and special celebrations with affordable facilities. Located in the Belgaum, we manage unforgettable memories for your most precious moments.
# Paragraph 31: Near Hanuman Nagar
# Paragraph 32: Bauxite Road, Belagavi
# Paragraph 33: Karnataka 590019
# Paragraph 34: +91 9449837586
# Paragraph 35: Call for bookings
# Paragraph 36: greengarden.bgm@gmail.com
# Paragraph 37: Email us anytime
# Paragraph 38: 9:00 AM - 10:00 PM
# Paragraph 39: Daily operations
# Paragraph 40: © 2024 Green Garden Function Hall. All rights reserved. | Marriage Hall in Belgaum | Function Hall Belagavi
# Image 1 URL: https://greengarden-belgaum.vercel.app/images/hall.jpg
# Image 2 URL: https://greengarden-belgaum.vercel.app/images/hall2.jpg
# Image 3 URL: https://greengarden-belgaum.vercel.app/images/hall3.jpg
# Image 4 URL: https://greengarden-belgaum.vercel.app/images/hall4.jpg
# Image 5 URL: https://images.pexels.com/photos/1444442/pexels-photo-1444442.jpeg?auto=compress&cs=tinysrgb&w=600
# Image 6 URL: https://images.pexels.com/photos/1024993/pexels-photo-1024993.jpeg?auto=compress&cs=tinysrgb&w=400
# Image 7 URL: https://images.pexels.com/photos/587741/pexels-photo-587741.jpeg?auto=compress&cs=tinysrgb&w=400
# Image 8 URL: https://images.pexels.com/photos/1444442/pexels-photo-1444442.jpeg?auto=compress&cs=tinysrgb&w=400
